# %% [markdown]
# ## Thu thập dữ liệu bằng API
# - Họ tên: Nguyễn Thế Hải
# - MSSV: 19120069
# - Nhiệm vụ: Code API
# ***
# - Họ tên: Trần Đức Thắng
# - MSSV: 19120130
# - Nhiệm vụ: Tìm hiểu API , hoàn thành các file notebook.

# %% [markdown]
# ## Môi trường code
# Dùng phiên bản các package như trong file "min_ds-env.yml"

# %% [markdown]
# ***
# ## Import

# %%
import requests
import requests_cache
from bs4 import BeautifulSoup
import time
import json
import re
import pandas as pd # Dùng để đọc và hiển thị file csv/tsv
from datetime import datetime, timedelta # Dùng để xử lý dữ liệu thời gian
# YOUR CODE HERE (OPTION) 
import csv

import urllib.robotparser # Kiểm tra file robot.txt có được phép crawl không

# %% [markdown]
# ***

# %% [markdown]
# [soundcloud](https://soundcloud.com/discover) là một trang web cho phép người dùng upload và chia sẻ các bài hát. Chúng ta sẽ thu thập thông tin về các nghệ sĩ, ban nhạc, podcast và người sáng tác âm nhạc trên trang Soundcloud.

# %% [markdown]
# ## Setup ở mức toàn cục

# %% [markdown]
# Đầu tiên, chúng ta sẽ setup các biến toàn cục:
# - Do số lượng request trong 1 phút bị giới hạn , vì vậy chúng ta cho chương trình sleep rồi requests lại. Biến `sleep_time` toàn cục để qui định số giây mà chương trình sẽ sleep (trong bài này cho 60 giây).
# - Số lượng mỗi file cần có ít nhất tầm > 1000 records vì vậy chúng ta sẽ setup biến `n_records` toàn cục để quy định số lượng records
# - 'Client ID là một dãy số độc nhất được đặt cho mỗi người truy cập website trên một thiết bị/trình duyệt web'.Vì vậy trong hàm này chúng ta setup biến `client_id` toàn cục quy định về Client ID

# %%
sleep_time = 60

# client id
client_id = 'o2BWXZ9TFWJtTjM1cF9OvS5BEYPk1hBS'

# number of records needed to crawl
n_records = 1000

# %% [markdown]
# Công việc trong phần này là viết hàm `collect_api` ở bên dưới. Hàm này có các input như sau:
# - `entities` là list , cho biết các từ khóa để lọc ra các đường link cần lấy. Ví dụ entity = {user , track , playlist} sẽ thu thập thông tin
# - `key_word` là chuỗi, cho biết là muốn tìm kiếm các thùng chứa với từ khóa nào. Ví dụ, key_word='blackpink'.
# - `per_page` là số nguyên, cho biết là muốn bao nhiêu kết quả trên một page

# %% [markdown]
# Output trả về của hàm collect_api:
#
# - results: là list các thùng chứa lấy được (list gồm "collection" của tất cả các trang).

# %%
def collect_api(entities, key_word, per_page):
    results = list()
    
    url = f'https://api-v2.soundcloud.com/search/{entities}?q={key_word}&client_id={client_id}&limit={per_page}'
    
    while(len(results) <= n_records):
        r = requests.get(url)
        
        # request failed
        if not r.ok:
            time.sleep(sleep_time)
            continue
              
        # extract items
        text = json.loads(r.text)
        results.extend(text['collection'])
        
        # find the next page
        if 'next_href' in text.keys():
            url = text['next_href']
            # add clinet_id to rul
            url = url + f'&client_id={client_id}'
        else:
            break
            
    return results

# %% [markdown]
# Sau khi đã lấy được danh sách thùng chứa gồm các "collection" của các trang. Chúng ta sử dụng biến `entities` để lọc các đường link cần lấy, với entities là các chuỗi:
# - `playlists` : có thể có nhiều track , chúng ta sẽ lấy 5 id bản nhạc đầu tiên trong danh sách playlists
# - `users` : danh sách người dùng
# - `track`:  danh sách các bản nhạc

# %%
# format playlists
def format_playlists(playlists):
    for playlist in playlists:
        del playlist['user']

        # get first 5 track ids in a playlist
        track_ids = ''
        count = playlist['track_count']
        for i in range(min(count, 5)):
            track = playlist['tracks'][i]
            track_ids = track_ids + ', ' + str(track['id'])
        playlist['track_ids'] = track_ids
        del playlist['tracks']
        
    return playlists


# format users
def format_users(users):
    for user in users:
        del user['creator_subscriptions']
        del user['creator_subscription']      
        
        user['pro_badges'] = user['badges']['pro']
        user['pro_unlimited_badges'] = user['badges']['pro_unlimited']        
        user['verified_badges'] = user['badges']['verified'] 
        del user['badges']
        
    return users


# format tracks
def format_tracks(tracks):
    for track in tracks:
        del track['publisher_metadata']
        del track['media']
        del track['user']
        
    return tracks

# %% [markdown]
# Hàm `write_file` sử dụng các input như sau:
# - file_name là tên của các entities
# - data là danh sách các thùng chứa gồm các "collection" của các trang.
# Chúng ta sử dụng `Pandas DataFrame` để chuyển dữ liệu data tổ chức sang không gian 2 chiều bao rows và columns.
# Ghi vào tập tin file_name.

# %%
def write_file(file_name, data):
    # convert to dataframe
    df = pd.DataFrame.from_dict(data)
    # write to file
    df.to_csv(file_name, index=False)

# %% [markdown]
# Sử dụng lại hàm `collect_api` để lấy dữ liệu.

# %%
def collect_data(entities, key_word):
    # collect api
    data = collect_api(entities, key_word, 101)
    
    # data cleaning
    if entities == 'users':
        data = format_users(data)
    if entities == 'tracks':
        data = format_tracks(data)
    if entities == 'playlists':
        data = format_playlists(data)
   
    # out to file
    write_file(f'{entities}.csv', data)

# %% [markdown]
# Chúng ta sẽ test một vài `key_word` cho chương trình với các entities mặc định, lưu vào trong file .csv.

# %%
collect_data('users', 'blackpink')
collect_data('tracks', 'blackpink')
collect_data('playlists', 'blackpink')

# %% [markdown]
# ## Đọc dữ liệu từ file users.csv

# %%
courses_tracks = pd.read_csv('users.csv')
courses_tracks
# Out:
#                                              avatar_url     city  \
# 0     https://i1.sndcdn.com/avatars-3YiljcXAvj7pU7Vb...      NaN
# 1     https://i1.sndcdn.com/avatars-000006487712-r86...  Jakarta
# 2     https://i1.sndcdn.com/avatars-Wse6DLdqgv7cYfAd...      NaN
# 3     https://i1.sndcdn.com/avatars-i49yuVyJxcoYwzdf...    Seoul
# 4     https://i1.sndcdn.com/avatars-RP5nzFyWTUqaFWtA...      NaN
# ...                                                 ...      ...
# 1005  https://i1.sndcdn.com/avatars-000737344153-6c6...      NaN
# 1006  https://i1.sndcdn.com/avatars-000579216768-g8q...      NaN
# 1007  https://i1.sndcdn.com/avatars-J3WxchBJI0ZdSUlh...      NaN
# 1008  https://i1.sndcdn.com/avatars-000298753519-rpc...      NaN
# 1009  https://i1.sndcdn.com/avatars-000559020588-rgv...      NaN
#
#       comments_count country_code            created_at description  \
# 0                  0          NaN  2019-08-23T10:12:13Z         NaN
# 1                  4           ID  2011-10-07T16:12:54Z         NaN
# 2                  0          NaN  2020-09-22T23:10:22Z         NaN
# 3                  0           KR  2019-11-13T18:52:41Z         NaN
# 4                  0          NaN  2019-03-07T01:12:29Z         NaN
# ...              ...          ...                   ...         ...
# 1005               0          NaN  2019-12-10T13:34:24Z         NaN
# 1006               5          NaN  2019-02-09T02:49:26Z         NaN
# 1007               0           US  2020-10-01T22:30:52Z         NaN
# 1008               0          NaN  2017-02-27T23:10:16Z         NaN
# 1009               0          NaN  2018-12-31T20:33:34Z         NaN
#
#       followers_count  followings_count first_name         full_name  ...  \
# 0              224250                 0        NaN               NaN  ...
# 1                5000                11      black        black pink  ...
# 2                3860                 0        NaN               NaN  ...
# 3                 549                 0  BLACKPINK         BLACKPINK  ...
# 4                 865                 2  BLACKPINK   BLACKPINK BLINK  ...
# ...               ...               ...        ...               ...  ...
# 1005                1                 0  BLACKPINK    BLACKPINK LOVE  ...
# 1006                3                 2  Blackpink      Blackpink Yg  ...
# 1007                1                 1        NaN               NaN  ...
# 1008               11                 1  Blackpink   Blackpink Blink  ...
# 1009                8                 3      black  black pink girls  ...
#
#                                              uri                         urn  \
# 0     https://api.soundcloud.com/users/688679639  soundcloud:users:688679639
# 1       https://api.soundcloud.com/users/7907166    soundcloud:users:7907166
# 2     https://api.soundcloud.com/users/884772682  soundcloud:users:884772682
# 3     https://api.soundcloud.com/users/733288924  soundcloud:users:733288924
# 4     https://api.soundcloud.com/users/600372183  soundcloud:users:600372183
# ...                                          ...                         ...
# 1005  https://api.soundcloud.com/users/747018262  soundcloud:users:747018262
# 1006  https://api.soundcloud.com/users/586147170  soundcloud:users:586147170
# 1007  https://api.soundcloud.com/users/888607462  soundcloud:users:888607462
# 1008  https://api.soundcloud.com/users/291902432  soundcloud:users:291902432
# 1009  https://api.soundcloud.com/users/564673212  soundcloud:users:564673212
#
#               username verified  \
# 0            BLACKPINK     True
# 1            blackpink    False
# 2            blackpink    False
# 3            BLACKPINK    False
# 4      BLACKPINK BLINK    False
# ...                ...      ...
# 1005    BLACKPINK LOVE    False
# 1006      Blackpink Yg    False
# 1007   BLACKPINK_BLINK    False
# 1008   Blackpink Blink    False
# 1009  black pink girls    False
#
#                                                 visuals  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     {'urn': 'soundcloud:users:733288924', 'enabled...
# 4     {'urn': 'soundcloud:users:600372183', 'enabled...
# ...                                                 ...
# 1005                                                NaN
# 1006                                                NaN
# 1007                                                NaN
# 1008                                                NaN
# 1009                                                NaN
#
#                                             station_urn  \
# 0     soundcloud:system-playlists:artist-stations:68...
# 1     soundcloud:system-playlists:artist-stations:79...
# 2     soundcloud:system-playlists:artist-stations:88...
# 3     soundcloud:system-playlists:artist-stations:73...
# 4     soundcloud:system-playlists:artist-stations:60...
# ...                                                 ...
# 1005  soundcloud:system-playlists:artist-stations:74...
# 1006  soundcloud:system-playlists:artist-stations:58...
# 1007  soundcloud:system-playlists:artist-stations:88...
# 1008  soundcloud:system-playlists:artist-stations:29...
# 1009  soundcloud:system-playlists:artist-stations:56...
#
#               station_permalink pro_badges pro_unlimited_badges  \
# 0     artist-stations:688679639      False                False
# 1       artist-stations:7907166      False                False
# 2     artist-stations:884772682      False                False
# 3     artist-stations:733288924      False                False
# 4     artist-stations:600372183      False                False
# ...                         ...        ...                  ...
# 1005  artist-stations:747018262      False                False
# 1006  artist-stations:586147170      False                False
# 1007  artist-stations:888607462      False                False
# 1008  artist-stations:291902432      False                False
# 1009  artist-stations:564673212      False                False
#
#       verified_badges
# 0                True
# 1               False
# 2               False
# 3               False
# 4               False
# ...               ...
# 1005            False
# 1006            False
# 1007            False
# 1008            False
# 1009            False
#
# [1010 rows x 32 columns]

# %% [markdown]
# ## Đọc dữ liệu từ file tracks.csv

# %%
courses_tracks = pd.read_csv('tracks.csv')
courses_tracks
# Out:
#                                             artwork_url caption  commentable  \
# 0     https://i1.sndcdn.com/artworks-000515081802-u0...     NaN         True
# 1     https://i1.sndcdn.com/artworks-000515083182-qp...     NaN         True
# 2     https://i1.sndcdn.com/artworks-000229999096-3i...     NaN         True
# 3     https://i1.sndcdn.com/artworks-000274869476-ct...     NaN         True
# 4     https://i1.sndcdn.com/artworks-000175418654-4i...     NaN         True
# ...                                                 ...     ...          ...
# 1005  https://i1.sndcdn.com/artworks-mbPiLJMNEj2toay...     NaN         True
# 1006  https://i1.sndcdn.com/artworks-PH6hMHVNEnz34zy...     NaN         True
# 1007  https://i1.sndcdn.com/artworks-aIFTc19BHUzV9vm...     NaN         True
# 1008  https://i1.sndcdn.com/artworks-000016550599-de...     NaN         True
# 1009  https://i1.sndcdn.com/artworks-000501087018-lu...     NaN         True
#
#       comment_count            created_at  \
# 0            9401.0  2019-04-04T16:23:08Z
# 1            2586.0  2019-04-04T16:26:35Z
# 2            4679.0  2017-06-22T10:25:58Z
# 3            3047.0  2017-12-25T12:00:02Z
# 4            4481.0  2016-08-08T18:43:20Z
# ...             ...                   ...
# 1005            0.0  2020-07-01T04:15:55Z
# 1006          284.0  2020-07-21T13:57:07Z
# 1007           14.0  2020-06-01T21:39:17Z
# 1008            0.0  2012-01-10T12:28:29Z
# 1009            2.0  2019-03-08T21:16:21Z
#
#                                             description  downloadable  \
# 0     BLACKPINK - Kill This Love\nDownload Album (MP...         False
# 1     블랙핑크 BLACKPINK - Don't Know What To Do\nDownlo...         False
# 2     #BLACKPINK #블랙핑크 #마지막처럼 #ASIFITSYOURLAST #TODA...         False
# 3     Remix by TEDDY, 24, Danny Chung \n\nTitle : SO...          True
# 4                                                   NaN         False
# ...                                                 ...           ...
# 1005                                                NaN         False
# 1006  Download : https://hypeddit.com/track/snn07h\n...         False
# 1007                                                NaN         False
# 1008  Warae warae onaka kakaete warae\r\nTanoshiku n...         False
# 1009                                                NaN         False
#
#       download_count  duration  full_duration  ...  \
# 0                0.0    186087         186087  ...
# 1                0.0    197086         197086  ...
# 2                0.0    213388         213388  ...
# 3              100.0    140029         140029  ...
# 4                0.0    245260         245260  ...
# ...              ...       ...            ...  ...
# 1005             0.0     41561          41561  ...
# 1006             4.0    211801         211801  ...
# 1007             0.0    178233         178233  ...
# 1008             0.0    285078         285078  ...
# 1009             0.0    102096         102096  ...
#
#                               urn    user_id  visuals  \
# 0     soundcloud:tracks:600933039  609199215      NaN
# 1     soundcloud:tracks:600934458  609199215      NaN
# 2     soundcloud:tracks:329471802  294531917      NaN
# 3     soundcloud:tracks:374190761  102916922      NaN
# 4     soundcloud:tracks:277386211  236716649      NaN
# ...                           ...        ...      ...
# 1005  soundcloud:tracks:850034938  846383797      NaN
# 1006  soundcloud:tracks:861849877  145898152      NaN
# 1007  soundcloud:tracks:832434946  466475376      NaN
# 1008   soundcloud:tracks:32959435    7907166      NaN
# 1009  soundcloud:tracks:587074152  600372183      NaN
#
#                                      waveform_url          display_date  \
# 0     https://wave.sndcdn.com/ejCQ0jBoBeBF_m.json  2019-04-04T16:23:08Z
# 1     https://wave.sndcdn.com/SgN7Mn4FAw3M_m.json  2019-04-04T16:26:35Z
# 2     https://wave.sndcdn.com/V0Y7raC7Adhv_m.json  2017-06-22T10:25:58Z
# 3     https://wave.sndcdn.com/tA6w8SOZdDeE_m.json  2017-12-25T12:00:02Z
# 4     https://wave.sndcdn.com/Vc0T1XqN5gOg_m.json  2016-08-08T18:43:20Z
# ...                                           ...                   ...
# 1005  https://wave.sndcdn.com/QSRwrBrESPmK_m.json  2020-07-01T04:15:55Z
# 1006  https://wave.sndcdn.com/VZJICPU6W8i8_m.json  2020-07-21T13:57:07Z
# 1007  https://wave.sndcdn.com/105Q3X9pr89A_m.json  2020-06-01T21:39:17Z
# 1008  https://wave.sndcdn.com/O518TeUScgzL_m.json  2012-01-10T12:28:29Z
# 1009  https://wave.sndcdn.com/tXz4dxlcBXEN_m.json  2019-03-08T21:16:21Z
#
#                                             station_urn  \
# 0     soundcloud:system-playlists:track-stations:600...
# 1     soundcloud:system-playlists:track-stations:600...
# 2     soundcloud:system-playlists:track-stations:329...
# 3     soundcloud:system-playlists:track-stations:374...
# 4     soundcloud:system-playlists:track-stations:277...
# ...                                                 ...
# 1005  soundcloud:system-playlists:track-stations:850...
# 1006  soundcloud:system-playlists:track-stations:861...
# 1007  soundcloud:system-playlists:track-stations:832...
# 1008  soundcloud:system-playlists:track-stations:329...
# 1009  soundcloud:system-playlists:track-stations:587...
#
#              station_permalink  \
# 0     track-stations:600933039
# 1     track-stations:600934458
# 2     track-stations:329471802
# 3     track-stations:374190761
# 4     track-stations:277386211
# ...                        ...
# 1005  track-stations:850034938
# 1006  track-stations:861849877
# 1007  track-stations:832434946
# 1008   track-stations:32959435
# 1009  track-stations:587074152
#
#                                     track_authorization  monetization_model  \
# 0     eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJnZW8iO...      NOT_APPLICABLE
# 1     eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJnZW8iO...      NOT_APPLICABLE
# 2     eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJnZW8iO...      NOT_APPLICABLE
# 3     eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJnZW8iO...      NOT_APPLICABLE
# 4     eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJnZW8iO...      NOT_APPLICABLE
# ...                                                 ...                 ...
# 1005  eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJnZW8iO...      NOT_APPLICABLE
# 1006  eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJnZW8iO...      NOT_APPLICABLE
# 1007  eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJnZW8iO...      NOT_APPLICABLE
# 1008  eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJnZW8iO...      NOT_APPLICABLE
# 1009  eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJnZW8iO...      NOT_APPLICABLE
#
#      policy
# 0     ALLOW
# 1     ALLOW
# 2     ALLOW
# 3     ALLOW
# 4     ALLOW
# ...     ...
# 1005  ALLOW
# 1006  ALLOW
# 1007  ALLOW
# 1008  ALLOW
# 1009  ALLOW
#
# [1010 rows x 45 columns]

# %% [markdown]
# ## Đọc dữ liệu từ file playlists.csv

# %%
courses_playlists = pd.read_csv('playlists.csv')
courses_playlists
# Out:
#                                             artwork_url            created_at  \
# 0                                                   NaN  2018-10-15T15:50:14Z
# 1                                                   NaN  2017-12-25T14:48:56Z
# 2                                                   NaN  2018-03-20T00:01:15Z
# 3     https://i1.sndcdn.com/artworks-6c8141af-033c-4...  2020-10-02T08:05:26Z
# 4                                                   NaN  2019-01-13T16:07:19Z
# ...                                                 ...                   ...
# 1001                                                NaN  2019-04-28T02:05:13Z
# 1002                                                NaN  2019-04-18T12:02:28Z
# 1003                                                NaN  2019-05-10T02:41:15Z
# 1004                                                NaN  2019-04-27T13:30:06Z
# 1005                                                NaN  2019-04-27T17:27:20Z
#
#       description   duration embeddable_by  genre          id      kind  \
# 0             NaN     656908           all    NaN   623598537  playlist
# 1             NaN  103595810          none    NaN   406348544  playlist
# 2             NaN   84464453           all   Kpop   476522658  playlist
# 3             NaN    1485062           all  Dance  1138455559  playlist
# 4             NaN   45806285           all    NaN   684966594  playlist
# ...           ...        ...           ...    ...         ...       ...
# 1001          NaN   12585925           all    NaN   766988553  playlist
# 1002          NaN   11541267           all    NaN   757188897  playlist
# 1003          NaN   12585925           all    NaN   776029629  playlist
# 1004          NaN   12585925           all    NaN   766405365  playlist
# 1005          NaN   12585925           all    NaN   766594935  playlist
#
#       label_name         last_modified  ... tag_list      title  \
# 0            NaN  2018-10-15T16:05:03Z  ...      NaN  blackpink
# 1            NaN  2021-02-18T17:31:50Z  ...      NaN  Blackpink
# 2            NaN  2021-07-05T04:54:08Z  ...      NaN  blackpink
# 3            NaN  2021-05-19T22:08:39Z  ...      NaN  THE ALBUM
# 4            NaN  2019-01-29T17:19:51Z  ...      NaN  Blackpink
# ...          ...                   ...  ...      ...        ...
# 1001         NaN  2019-04-28T02:05:21Z  ...      NaN  blackpink
# 1002         NaN  2019-04-18T12:02:48Z  ...      NaN  blackpink
# 1003         NaN  2019-05-10T02:42:02Z  ...      NaN  blackpink
# 1004         NaN  2019-04-27T13:30:09Z  ...      NaN  blackpink
# 1005         NaN  2019-04-27T17:27:23Z  ...      NaN  blackpink
#
#                                                   uri    user_id set_type  \
# 0      https://api.soundcloud.com/playlists/623598537  508598199      NaN
# 1      https://api.soundcloud.com/playlists/406348544  257009086      NaN
# 2      https://api.soundcloud.com/playlists/476522658  299633379      NaN
# 3     https://api.soundcloud.com/playlists/1138455559  688679639    album
# 4      https://api.soundcloud.com/playlists/684966594  522440574      NaN
# ...                                               ...        ...      ...
# 1001   https://api.soundcloud.com/playlists/766988553  416176383      NaN
# 1002   https://api.soundcloud.com/playlists/757188897  416627478      NaN
# 1003   https://api.soundcloud.com/playlists/776029629  416848206      NaN
# 1004   https://api.soundcloud.com/playlists/766405365  419093001      NaN
# 1005   https://api.soundcloud.com/playlists/766594935  416848365      NaN
#
#       is_album          published_at          display_date track_count  \
# 0        False  2018-10-15T15:50:14Z  2018-10-15T15:50:14Z           2
# 1        False  2017-12-25T14:48:56Z  2017-12-25T14:48:56Z         358
# 2        False  2018-03-20T00:01:15Z  2018-03-20T00:01:15Z         373
# 3         True  2020-10-02T00:00:00Z  2020-10-02T00:00:00Z           8
# 4        False  2019-01-13T16:07:19Z  2019-01-13T16:07:19Z         139
# ...        ...                   ...                   ...         ...
# 1001     False  2019-04-28T02:05:13Z  2019-04-28T02:05:13Z          47
# 1002     False  2019-04-18T12:02:28Z  2019-04-18T12:02:28Z          42
# 1003     False  2019-05-10T02:41:15Z  2019-05-10T02:41:15Z          47
# 1004     False  2019-04-27T13:30:06Z  2019-04-27T13:30:06Z          47
# 1005     False  2019-04-27T17:27:20Z  2019-04-27T17:27:20Z          47
#
#                                               track_ids
# 0                                , 329471802, 401058264
# 1     , 360260393, 295987850, 307372211, 343190783, ...
# 2     , 350872552, 308578451, 206558035, 329468204, ...
# 3     , 847247068, 883389634, 903272074, 903272005, ...
# 4     , 277386211, 277382742, 290812196, 290812191, ...
# ...                                                 ...
# 1001  , 603636444, 544449522, 310637766, 448743879, ...
# 1002  , 544449522, 310637766, 448743879, 574858791, ...
# 1003  , 603636444, 544449522, 310637766, 448743879, ...
# 1004  , 603636444, 544449522, 310637766, 448743879, ...
# 1005  , 603636444, 544449522, 310637766, 448743879, ...
#
# [1006 rows x 32 columns]
